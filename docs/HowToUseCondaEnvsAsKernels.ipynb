# %% [markdown]
# # How to use and switch between Conda Environments as Kernels in Vertex AI's Jupyter Lab

# %% [markdown]
# There are two major steps in using a conda virtual environment as a kernel in JupyterLabs. You first need to create your conda environment with your specified software packages. Then, you can register that as a kernel. Depending on your settings this might happen automatically. The below insructions walk through the necessary steps.

# %% [markdown]
# ### Setting up Jupyter lab to create conda environment kernels

# %% [markdown]
# List your conda environments. If you havent created a conda environment yet the only conda environment that should be listed is __base__.

# %%
conda env list
# Out:
# # conda environments:
# #
# base                  *  /opt/conda
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# You can run the command below to list the jupyter kernels which later we will use to also confirm that the conda environments are connected to jupyter kernels.

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3    /opt/conda/share/jupyter/kernels/python3

# %% [markdown]
# Similar to the jupyter kernelspec command the nb_conda_kernels command is used to list conda environments and any shared jupyter kernels (e.g. python3), as you can see the 'conda-root-py' conda kernel which is your __base__ conda environment.

# %%
# !python -m nb_conda_kernels list
# Out:
# [ListKernelSpecs] [nb_conda_kernels] enabled, 1 kernels found
# Available kernels:
#   python3          /opt/conda/share/jupyter/kernels/python3
#   conda-root-py    /opt/conda/share/jupyter/kernels/python3

# %% [markdown]
# Its important to note that the nb_conda_kernels command will list jupyter kernels and conda environments but that does not mean the kernelspec command will do the same (it only lists kernels). This is because the conda environments must be in a shared file location that jupyter will identify as kernels.
#
#
# nb_conda_kernels uses tools such as nbconvert, voila, papermill, etc. that make this happen but before that we need to add a jupyter_config.json file.
#
# This file will configure the kernelspec_path (path where they look for kernels) to tell the nb_conda_kernel tools to add dynamically the conda environment to the kernel list as the 'user' level.

# %% [markdown]
# To get started we'll first create a __jupyter_config.json__ file within the __.jupyter__ directory.
#
# You can find the path to the .jupyter directory by running:

# %%
# !jupyter --config-dir
# Out:
# /home/jupyter/.jupyter

# %% [markdown]
# In your terminal you can enter the following command to create the jupyter_config.json directly in the correct directory:

# %% [markdown]
# ```
# nano /home/jupyter/.jupyter/jupyter_config.json
#
# ```

# %% [markdown]
# enter this script exactly into jupyter_config.json
# ```
# {
#   "CondaKernelSpecManager": {
#     "kernelspec_path": "--user"
#   }
# }
# ```
# Once thats done save your changes and exit nano. To exit do the following:
# - Press __Ctrl + X__
# - Type __Y__
# - Press __Enter__

# %% [markdown]
# Now you can run nb_conda_kernels command to jumpstart the process and run kernelspecs to confirm that the conda base environment is a jupyter kernel

# %%
# !python -m nb_conda_kernels list
# Out:
# [ListKernelSpecs] Installed kernelspec conda-root-py in /home/jupyter/.local/share/jupyter/kernels/conda-root-py
# [ListKernelSpecs] [nb_conda_kernels] enabled, 1 kernels found
# Available kernels:
#   conda-root-py    /opt/conda/share/jupyter/kernels/python3

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   conda-root-py    /home/jupyter/.local/share/jupyter/kernels/conda-root-py
#   python3          /opt/conda/share/jupyter/kernels/python3

# %% [markdown]
# You should see that nb_conda_kernels has found 1 kernel and that kernelspecs now lists the conda-root-py environment

# %% [markdown]
# __Warning: Give it about 2-5 minutes before you switch your jupyter kernel to give your system time to show your conda environments as kernels.__
#
# ### Switch Your Kernel
#
# You can then switch your kernel by clicking the __python 3__ kernel located in the top right hand corner, click the dropdown menu, then select your kernel and click __Select__.
#
# Another way to view your kernels is by clicking New Launcher located in the left side of your screen (the blue rectangle).

# %% [markdown]
# ### Create a conda environment

# %% [markdown]
# For every conda env make sure you either:
#
# - Install pip, then install jupterlab through pip seen in example A
#
# or
# - Install ipykernel as an alternative seen in example B
#
# In the example below we are using a environment yaml file which makes is easier to install multiple dependencies at once. The following file will list:
#
# - name: The name of you environment
# - channels: channels such as bioconda, conda-forge, etc. that are required to install your dependencies
# - dependencies: tool that you wish to install such as python, pandas, fastqc, etc.

# %% [markdown]
# __env.yml file EXAMPLES__
#
#
# __A__
# ```
# name: sample3
# channels:
# - bioconda
# dependencies:
# - python= 3.9
# - pip
# - pip:
#   # works for regular pip packages
#   - jupyterlab
# - fastqc
# ```
# __B__
# ```
# name: sample4
# channels:
# - bioconda
# dependencies:
# - python= 3.9
# - ipykernel
# - fastqc
# ```

# %% [markdown]
# For our example we will create a yaml file named env.yml and enter in the information written in example __B__

# %% [markdown]
# Then create your conda environment!

# %%
conda env create --file env.yml
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# Downloading and Extracting Packages
# python_abi-3.9       | 4 KB      | ##################################### | 100%
# fonts-conda-ecosyste | 4 KB      | ##################################### | 100%
# harfbuzz-5.3.0       | 2.2 MB    | ##################################### | 100%
# xorg-libice-1.0.10   | 58 KB     | ##################################### | 100%
# xorg-libx11-1.7.2    | 941 KB    | ##################################### | 100%
# xorg-libxi-1.7.10    | 46 KB     | ##################################### | 100%
# pyzmq-24.0.1         | 483 KB    | ##################################### | 100%
# xorg-xproto-7.0.31   | 73 KB     | ##################################### | 100%
# ipykernel-6.16.1     | 100 KB    | ##################################### | 100%
# perl-5.32.1          | 14.4 MB   | ##################################### | 100%
# libstdcxx-ng-12.2.0  | 4.3 MB    | ##################################### | 100%
# xorg-kbproto-1.0.7   | 27 KB     | ##################################### | 100%
# giflib-5.2.1         | 77 KB     | ##################################### | 100%
# xorg-xextproto-7.3.0 | 28 KB     | ##################################### | 100%
# jupyter_client-7.4.3 | 91 KB     | ##################################### | 100%
# _openmp_mutex-4.5    | 23 KB     | ##################################### | 100%
# stack_data-0.5.1     | 24 KB     | ##################################### | 100%
# xorg-recordproto-1.1 | 8 KB      | ##################################### | 100%
# xorg-renderproto-0.1 | 9 KB      | ##################################### | 100%
# setuptools-65.5.0    | 768 KB    | ##################################### | 100%
# xorg-libxtst-1.2.3   | 31 KB     | ##################################### | 100%
# xorg-libxfixes-5.0.3 | 18 KB     | ##################################### | 100%
# cairo-1.16.0         | 1.5 MB    | ##################################### | 100%
# krb5-1.19.3          | 1.4 MB    | ##################################### | 100%
# sqlite-3.39.4        | 789 KB    | ##################################### | 100%
# six-1.16.0           | 14 KB     | ##################################### | 100%
# python-3.9.13        | 26.7 MB   | ##################################### | 100%
# readline-8.1.2       | 291 KB    | ##################################### | 100%
# xorg-inputproto-2.3. | 19 KB     | ##################################### | 100%
# libgomp-12.2.0       | 455 KB    | ##################################### | 100%
# openssl-3.0.5        | 2.8 MB    | ##################################### | 100%
# jupyter_core-4.11.1  | 81 KB     | ##################################### | 100%
# ncurses-6.3          | 1002 KB   | ##################################### | 100%
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
# xorg-libxext-1.3.4   | 54 KB     | ##################################### | 100%
# asttokens-2.0.8      | 24 KB     | ##################################### | 100%
# debugpy-1.6.3        | 2.0 MB    | ##################################### | 100%
# fastqc-0.11.9        | 9.7 MB    | ##################################### | 100%
# xorg-fixesproto-5.0  | 9 KB      | ##################################### | 100%
# libzlib-1.2.13       | 64 KB     | ##################################### | 100%
# xorg-libxrender-0.9. | 32 KB     | ##################################### | 100%
# traitlets-5.5.0      | 85 KB     | ##################################### | 100%
# pixman-0.40.0        | 627 KB    | ##################################### | 100%
# openjdk-17.0.3       | 172.4 MB  | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# libgcc-ng-12.2.0     | 936 KB    | ##################################### | 100%
# fonts-conda-forge-1  | 4 KB      | ##################################### | 100%
# pip-22.3             | 1.5 MB    | ##################################### | 100%
# graphite2-1.3.13     | 102 KB    | ##################################### | 100%
# psutil-5.9.3         | 348 KB    | ##################################### | 100%
# libsqlite-3.39.4     | 803 KB    | ##################################### | 100%
# tzdata-2022e         | 118 KB    | ##################################### | 100%
# gettext-0.21.1       | 4.1 MB    | ##################################### | 100%
# tornado-6.2          | 658 KB    | ##################################### | 100%
# pure_eval-0.2.2      | 14 KB     | ##################################### | 100%
# xorg-libsm-1.2.3     | 26 KB     | ##################################### | 100%
# zlib-1.2.13          | 92 KB     | ##################################### | 100%
# ld_impl_linux-64-2.3 | 759 KB    | ##################################### | 100%
# executing-1.1.1      | 23 KB     | ##################################### | 100%
# wheel-0.37.1         | 31 KB     | ##################################### | 100%
# ipython-8.5.0        | 552 KB    | ##################################### | 100%
# nest-asyncio-1.5.6   | 10 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate sample4
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# You can run nb_conda_kernel list again to jumpstart the jupyter kernel process

# %%
# !python -m nb_conda_kernels list
# Out:
# [ListKernelSpecs] Removing existing kernelspec in /home/jupyter/.local/share/jupyter/kernels/conda-root-py
# [ListKernelSpecs] Installed kernelspec conda-root-py in /home/jupyter/.local/share/jupyter/kernels/conda-root-py
# [ListKernelSpecs] Installed kernelspec conda-env-sample4-py in /home/jupyter/.local/share/jupyter/kernels/conda-env-sample4-py
# [ListKernelSpecs] [nb_conda_kernels] enabled, 2 kernels found
# Available kernels:
#   conda-env-sample4-py    /opt/conda/envs/sample4/share/jupyter/kernels/python3
#   conda-root-py           /opt/conda/share/jupyter/kernels/python3

# %% [markdown]
# Now check that your conda environment is a jupyter kernel

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   conda-env-sample4-py    /home/jupyter/.local/share/jupyter/kernels/conda-env-sample4-py
#   conda-root-py           /home/jupyter/.local/share/jupyter/kernels/conda-root-py
#   python3                 /opt/conda/share/jupyter/kernels/python3

# %% [markdown]
# You should see our conda environment named sample4 but written as __conda-env-sample4-py__

# %% [markdown]
# ### Using Mamba

# %% [markdown]
# Mamba is conda but faster you can utilize it by installing it into the conda base

# %%
# !conda install mamba -n base -c conda-forge

# %% [markdown]
# The only difference will be the speed and also the commands will be 'mamba' not
# 'conda'

# %%
# !mamba env create -f env.yml
# Out:
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# conda-forge/noarch   ━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# bioconda/linux-64    ╸━━━━━━━━━━━━━━━╸━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# bioconda/noarch      ━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/linux-64   ━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1sbioconda/linux-64                                             No change
# bioconda/noarch                                               No change
# pkgs/main/linux-64                                            No change
# pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
# pkgs/r/linux-64                                               No change
# [+] 0.2s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━ 104.1kB /  ??.?MB @ 621.8kB/s  0.2s
# conda-forge/noarch   ━━━━╸━━━━━━━━━━━━━━━╸━━ 158.7kB /  ??.?MB @ 948.8kB/s  0.2s[+] 0.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━ 534.8kB /  ??.?MB @   2.0MB/s  0.3s
# conda-forge/noarch   ━━━━━━╸━━━━━━━━━━━━━━━━ 530.2kB /  ??.?MB @   2.0MB/s  0.3s[+] 0.4s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━ 843.0kB /  ??.?MB @   2.3MB/s  0.4s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   1.0MB /  ??.?MB @   2.7MB/s  0.4s[+] 0.5s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   1.3MB /  ??.?MB @   2.8MB/s  0.5s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   1.5MB /  ??.?MB @   3.2MB/s  0.5s[+] 0.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━   1.8MB /  ??.?MB @   3.2MB/s  0.6s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━   2.0MB /  ??.?MB @   3.5MB/s  0.6s[+] 0.7s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━   2.3MB /  ??.?MB @   3.4MB/s  0.7s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   2.4MB /  ??.?MB @   3.6MB/s  0.7s[+] 0.8s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━   2.7MB /  ??.?MB @   3.5MB/s  0.8s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   2.8MB /  ??.?MB @   3.7MB/s  0.8s[+] 0.9s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━   3.2MB /  ??.?MB @   3.6MB/s  0.9s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━━   3.4MB /  ??.?MB @   3.9MB/s  0.9s[+] 1.0s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━   3.6MB /  ??.?MB @   3.7MB/s  1.0s
# conda-forge/noarch   ╸━━━━━━━━━━━━━━━╸━━━━━━   3.9MB /  ??.?MB @   4.0MB/s  1.0s[+] 1.1s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━   4.1MB /  ??.?MB @   3.8MB/s  1.1s
# conda-forge/noarch   ━━╸━━━━━━━━━━━━━━━╸━━━━   4.4MB /  ??.?MB @   4.1MB/s  1.1s[+] 1.2s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   4.6MB /  ??.?MB @   3.9MB/s  1.2s
# conda-forge/noarch   ━━━━╸━━━━━━━━━━━━━━━╸━━   4.9MB /  ??.?MB @   4.2MB/s  1.2s[+] 1.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━   5.0MB /  ??.?MB @   3.9MB/s  1.3s
# conda-forge/noarch   ━━━━━━╸━━━━━━━━━━━━━━━━   5.4MB /  ??.?MB @   4.3MB/s  1.3s[+] 1.4s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━   5.5MB /  ??.?MB @   4.0MB/s  1.4s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   5.9MB /  ??.?MB @   4.3MB/s  1.4s[+] 1.5s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   6.0MB /  ??.?MB @   4.1MB/s  1.5s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   6.4MB /  ??.?MB @   4.3MB/s  1.5s[+] 1.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━   6.5MB /  ??.?MB @   4.1MB/s  1.6s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━   6.7MB /  ??.?MB @   4.3MB/s  1.6s[+] 1.7s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━   7.0MB /  ??.?MB @   4.2MB/s  1.7s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   7.2MB /  ??.?MB @   4.3MB/s  1.7s[+] 1.8s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━   7.5MB /  ??.?MB @   4.2MB/s  1.8s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   7.7MB /  ??.?MB @   4.3MB/s  1.8s[+] 1.9s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━   8.0MB /  ??.?MB @   4.3MB/s  1.9s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━━   8.1MB /  ??.?MB @   4.3MB/s  1.9s[+] 2.0s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━   8.5MB /  ??.?MB @   4.3MB/s  2.0s
# conda-forge/noarch   ╸━━━━━━━━━━━━━━━╸━━━━━━   8.6MB /  ??.?MB @   4.3MB/s  2.0s[+] 2.1s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.1s
# conda-forge/noarch   ━╸━━━━━━━━━━━━━━━╸━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.1s[+] 2.2s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.2s
# conda-forge/noarch   ━╸━━━━━━━━━━━━━━━╸━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.2s[+] 2.3s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.3s
# conda-forge/noarch   ━╸━━━━━━━━━━━━━━━╸━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.3s[+] 2.4s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━   8.7MB @   4.3MB/s             2.4s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━━━━━━━   8.9MB @   4.3MB/s Finalizing  2.4s[+] 2.5s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.5s[+] 2.6s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.6s[+] 2.7s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.7s[+] 2.8s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.8s[+] 2.9s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   8.7MB /  ??.?MB @   4.3MB/s  2.9sconda-forge/noarch                                 @   4.3MB/s  2.5s
# [+] 3.0s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  10.1MB /  ??.?MB @   3.4MB/s  3.0s[+] 3.1s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  11.1MB /  ??.?MB @   3.6MB/s  3.1s[+] 3.2s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  11.5MB /  ??.?MB @   3.6MB/s  3.2s[+] 3.3s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  11.9MB /  ??.?MB @   3.7MB/s  3.3s[+] 3.4s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  12.3MB /  ??.?MB @   3.6MB/s  3.4s[+] 3.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━  12.7MB /  ??.?MB @   3.6MB/s  3.5s[+] 3.6s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  13.1MB /  ??.?MB @   3.7MB/s  3.6s[+] 3.7s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━  13.5MB /  ??.?MB @   3.6MB/s  3.7s[+] 3.8s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━╸━  14.0MB /  ??.?MB @   3.7MB/s  3.8s[+] 3.9s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  14.2MB /  ??.?MB @   3.7MB/s  3.9s[+] 4.0s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  14.6MB /  ??.?MB @   3.7MB/s  4.0s[+] 4.1s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  14.9MB /  ??.?MB @   3.7MB/s  4.1s[+] 4.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  15.2MB /  ??.?MB @   3.7MB/s  4.2s[+] 4.3s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  15.6MB /  ??.?MB @   3.7MB/s  4.3s[+] 4.4s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  16.1MB /  ??.?MB @   3.7MB/s  4.4s[+] 4.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  16.5MB /  ??.?MB @   3.7MB/s  4.5s[+] 4.6s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━  17.0MB /  ??.?MB @   3.7MB/s  4.6s[+] 4.7s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━  17.4MB /  ??.?MB @   3.7MB/s  4.7s[+] 4.8s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━  17.9MB /  ??.?MB @   3.7MB/s  4.8s[+] 4.9s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  18.4MB /  ??.?MB @   3.8MB/s  4.9s[+] 5.0s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  18.8MB /  ??.?MB @   3.8MB/s  5.0s[+] 5.1s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  19.3MB /  ??.?MB @   3.8MB/s  5.1s[+] 5.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  19.7MB /  ??.?MB @   3.8MB/s  5.2s[+] 5.3s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  20.2MB /  ??.?MB @   3.8MB/s  5.3s[+] 5.4s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  20.7MB /  ??.?MB @   3.8MB/s  5.4s[+] 5.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  21.1MB /  ??.?MB @   3.9MB/s  5.5s[+] 5.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  21.1MB /  ??.?MB @   3.9MB/s  5.6s[+] 5.7s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━  22.0MB /  ??.?MB @   3.9MB/s  5.7s[+] 5.8s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━  22.5MB /  ??.?MB @   3.9MB/s  5.8s[+] 5.9s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━  23.0MB /  ??.?MB @   3.9MB/s  5.9s[+] 6.0s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  23.6MB /  ??.?MB @   4.0MB/s  6.0s[+] 6.1s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  24.2MB /  ??.?MB @   4.0MB/s  6.1s[+] 6.2s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  6.2s[+] 6.3s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  6.3s[+] 6.4s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  6.4s[+] 6.5s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  6.5s[+] 6.6s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  6.6s[+] 6.7s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  6.7s[+] 6.8s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  6.8s[+] 6.9s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  6.9s[+] 7.0s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  7.0s[+] 7.1s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  7.1s[+] 7.2s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  7.2s[+] 7.3s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  7.3s[+] 7.4s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  7.4s[+] 7.5s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.4MB /  ??.?MB @   4.0MB/s  7.5s[+] 7.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  24.5MB @   4.0MB/s Finalizing  7.6s[+] 7.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  24.5MB @   4.0MB/s Finalizing  7.7s[+] 7.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  24.5MB @   4.0MB/s Finalizing  7.8s[+] 7.9s
# [+] 8.0s
# [+] 8.1s
# [+] 8.2s
# [+] 8.3s
# [+] 8.4s
# [+] 8.5s
# [+] 8.6s
# [+] 8.7s
# [+] 8.8s
# [+] 8.9s
# [+] 9.0s
# [+] 9.1s
# [+] 9.2s
# [+] 9.3s
# conda-forge/linux-64                               @   4.0MB/s  7.9s
#
#
# Looking for: ['snakemake', 'pip']
#
#
# Transaction
#
#   Prefix: /opt/conda/envs/snakemake
#
#   Updating specs:
#
#    - snakemake
#    - pip
#
#
#   Package                             Version  Build                Channel                    Size
# ─────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                         0.1  conda_forge          conda-forge/linux-64     Cached
#   + _openmp_mutex                         4.5  2_gnu                conda-forge/linux-64     Cached
#   + abseil-cpp                     20211102.0  h27087fc_1           conda-forge/linux-64     Cached
#   + aioeasywebdav                       2.4.0  pyha770c72_0         conda-forge/noarch         13kB
#   + aiohttp                             3.8.1  py310h5764c6d_1      conda-forge/linux-64      599kB
#   + aiosignal                           1.2.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + amply                               0.1.5  pyhd8ed1ab_0         conda-forge/noarch         21kB
#   + appdirs                             1.4.4  pyh9f0ad1d_0         conda-forge/noarch       Cached
#   + async-timeout                       4.0.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + attmap                             0.13.2  pyhd8ed1ab_0         conda-forge/noarch         14kB
#   + attrs                              22.1.0  pyh71513ae_1         conda-forge/noarch         49kB
#   + backports                             1.0  py_2                 conda-forge/noarch       Cached
#   + backports.functools_lru_cache       1.6.4  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + bcrypt                              3.2.2  py310h5764c6d_0      conda-forge/linux-64       45kB
#   + boto3                             1.24.44  pyhd8ed1ab_0         conda-forge/noarch         74kB
#   + botocore                          1.27.44  pyhd8ed1ab_0         conda-forge/noarch          6MB
#   + brotlipy                            0.7.0  py310h5764c6d_1004   conda-forge/linux-64      350kB
#   + bzip2                               1.0.8  h7f98852_4           conda-forge/linux-64     Cached
#   + c-ares                             1.18.1  h7f98852_0           conda-forge/linux-64     Cached
#   + ca-certificates                 2022.6.15  ha878542_0           conda-forge/linux-64     Cached
#   + cachetools                          5.0.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + certifi                         2022.6.15  py310hff52083_0      conda-forge/linux-64      159kB
#   + cffi                               1.15.1  py310h255011f_0      conda-forge/linux-64      237kB
#   + charset-normalizer                  2.1.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + coin-or-cbc                        2.10.8  h3786ebc_0           conda-forge/linux-64        1MB
#   + coin-or-cgl                        0.60.6  h6f57e76_1           conda-forge/linux-64      603kB
#   + coin-or-clp                        1.17.7  hc56784d_1           conda-forge/linux-64        1MB
#   + coin-or-osi                       0.108.7  h2720bb7_1           conda-forge/linux-64      450kB
#   + coin-or-utils                      2.11.6  h202d8b1_1           conda-forge/linux-64      758kB
#   + coincbc                            2.10.8  0_metapackage        conda-forge/noarch         10kB
#   + commonmark                          0.9.1  py_0                 conda-forge/noarch       Cached
#   + configargparse                      1.5.3  pyhd8ed1ab_0         conda-forge/noarch         33kB
#   + connection_pool                     0.0.3  pyhd3deb0d_0         conda-forge/noarch          8kB
#   + cryptography                       37.0.1  py310h9ce1e76_0      pkgs/main/linux-64          2MB
#   + dataclasses                           0.8  pyhc8e2a94_3         conda-forge/noarch       Cached
#   + datrie                              0.8.2  py310h6acc77f_3      conda-forge/linux-64      772kB
#   + decorator                           5.1.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + defusedxml                          0.7.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + docutils                             0.19  py310hff52083_0      conda-forge/linux-64      781kB
#   + dpath                               2.0.6  py310hff52083_1      conda-forge/linux-64       24kB
#   + dropbox                           11.33.0  pyhd8ed1ab_0         conda-forge/noarch        956kB
#   + filechunkio                           1.8  py_2                 conda-forge/noarch          5kB
#   + filelock                            3.7.1  pyhd8ed1ab_0         conda-forge/noarch         12kB
#   + frozenlist                          1.3.0  py310h5764c6d_1      conda-forge/linux-64       44kB
#   + ftputil                             5.0.4  pyhd8ed1ab_0         conda-forge/noarch         43kB
#   + future                             0.18.2  py310hff52083_5      conda-forge/linux-64      755kB
#   + gitdb                               4.0.9  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + gitpython                          3.1.27  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + google-api-core                     2.8.2  pyhd8ed1ab_0         conda-forge/noarch         72kB
#   + google-api-python-client           2.55.0  pyhd8ed1ab_0         conda-forge/noarch          5MB
#   + google-auth                         2.9.1  pyh6c4a22f_0         conda-forge/noarch         92kB
#   + google-auth-httplib2                0.1.0  pyhd8ed1ab_1         conda-forge/noarch       Cached
#   + google-cloud-core                   2.3.2  pyhd8ed1ab_0         conda-forge/noarch         28kB
#   + google-cloud-storage                2.4.0  pyh6c4a22f_0         conda-forge/noarch       Cached
#   + google-crc32c                       1.1.2  py310he8fe98e_3      conda-forge/linux-64       24kB
#   + google-resumable-media              2.3.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + googleapis-common-protos           1.56.4  py310hff52083_0      conda-forge/linux-64      126kB
#   + grpc-cpp                           1.48.0  h00ec82a_0           conda-forge/linux-64        5MB
#   + grpcio                             1.48.0  py310h70d52b7_0      conda-forge/linux-64      825kB
#   + httplib2                           0.20.4  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + idna                                  3.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + importlib-metadata                 4.11.4  py310hff52083_0      conda-forge/linux-64       34kB
#   + importlib_resources                 5.9.0  pyhd8ed1ab_0         conda-forge/noarch         28kB
#   + iniconfig                           1.1.1  pyh9f0ad1d_0         conda-forge/noarch          8kB
#   + jinja2                              3.1.2  pyhd8ed1ab_1         conda-forge/noarch       Cached
#   + jmespath                            1.0.1  pyhd8ed1ab_0         conda-forge/noarch         21kB
#   + jsonschema                          4.9.1  pyhd8ed1ab_0         conda-forge/noarch         64kB
#   + jupyter_core                       4.11.1  py310hff52083_0      conda-forge/linux-64       84kB
#   + ld_impl_linux-64                   2.36.1  hea4e1c9_2           conda-forge/linux-64     Cached
#   + libblas                             3.9.0  15_linux64_openblas  conda-forge/linux-64     Cached
#   + libcblas                            3.9.0  15_linux64_openblas  conda-forge/linux-64     Cached
#   + libcrc32c                           1.1.2  h9c3ff4c_0           conda-forge/linux-64     Cached
#   + libffi                              3.4.2  h7f98852_5           conda-forge/linux-64     Cached
#   + libgcc-ng                          12.1.0  h8d9b700_16          conda-forge/linux-64     Cached
#   + libgfortran-ng                     12.1.0  h69a702a_16          conda-forge/linux-64     Cached
#   + libgfortran5                       12.1.0  hdcd56e2_16          conda-forge/linux-64     Cached
#   + libgomp                            12.1.0  h8d9b700_16          conda-forge/linux-64     Cached
#   + liblapack                           3.9.0  15_linux64_openblas  conda-forge/linux-64     Cached
#   + liblapacke                          3.9.0  15_linux64_openblas  conda-forge/linux-64       13kB
#   + libnsl                              2.0.0  h7f98852_0           conda-forge/linux-64     Cached
#   + libopenblas                        0.3.20  pthreads_h78a6416_1  conda-forge/linux-64     Cached
#   + libprotobuf                        3.20.1  h6239696_0           conda-forge/linux-64     Cached
#   + libsodium                          1.0.18  h36c2ea0_1           conda-forge/linux-64     Cached
#   + libstdcxx-ng                       12.1.0  ha89aaad_16          conda-forge/linux-64     Cached
#   + libuuid                            2.32.1  h7f98852_1000        conda-forge/linux-64     Cached
#   + libzlib                            1.2.12  h166bdaf_2           conda-forge/linux-64     Cached
#   + logmuse                             0.2.6  pyh8c360ce_0         conda-forge/noarch         11kB
#   + markupsafe                          2.1.1  py310h5764c6d_1      conda-forge/linux-64       23kB
#   + multidict                           6.0.2  py310h5764c6d_1      conda-forge/linux-64       53kB
#   + nbformat                            5.4.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + ncurses                               6.3  h27087fc_1           conda-forge/linux-64     Cached
#   + numpy                              1.23.1  py310h53a5b5f_0      conda-forge/linux-64        7MB
#   + oauth2client                        4.1.3  py_0                 conda-forge/noarch         67kB
#   + openssl                             3.0.5  h166bdaf_1           conda-forge/linux-64     Cached
#   + packaging                            21.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pandas                              1.4.3  py310h769672d_0      conda-forge/linux-64       13MB
#   + paramiko                           2.11.0  pyhd8ed1ab_0         conda-forge/noarch        143kB
#   + peppy                              0.32.0  pyhd8ed1ab_1         conda-forge/noarch         26kB
#   + pip                                22.2.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pkgutil-resolve-name               1.3.10  pyhd8ed1ab_0         conda-forge/noarch          9kB
#   + plac                                1.3.5  pyhd8ed1ab_0         conda-forge/noarch         23kB
#   + pluggy                              1.0.0  py310hff52083_3      conda-forge/linux-64       26kB
#   + ply                                  3.11  py_1                 conda-forge/noarch         45kB
#   + prettytable                         3.3.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + protobuf                           3.20.1  py310hd8f1fbe_0      conda-forge/linux-64      333kB
#   + psutil                              5.9.1  py310h5764c6d_0      conda-forge/linux-64      359kB
#   + pulp                                2.6.0  py310hff52083_1      conda-forge/linux-64      128kB
#   + py                                 1.11.0  pyh6c4a22f_0         conda-forge/noarch         76kB
#   + pyasn1                              0.4.8  py_0                 conda-forge/noarch       Cached
#   + pyasn1-modules                      0.2.7  py_0                 conda-forge/noarch       Cached
#   + pycparser                            2.21  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pygments                           2.12.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pynacl                              1.5.0  py310h5764c6d_1      conda-forge/linux-64        1MB
#   + pyopenssl                          22.0.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pyparsing                           3.0.9  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pyrsistent                         0.18.1  py310h5764c6d_1      conda-forge/linux-64       95kB
#   + pysftp                              0.2.9  py_1                 conda-forge/noarch         16kB
#   + pysocks                             1.7.1  py310hff52083_5      conda-forge/linux-64       29kB
#   + pytest                              7.1.2  py310hff52083_0      conda-forge/linux-64      476kB
#   + python                             3.10.5  ha86cf86_0_cpython   conda-forge/linux-64       30MB
#   + python-dateutil                     2.8.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + python-fastjsonschema              2.16.1  pyhd8ed1ab_0         conda-forge/noarch        249kB
#   + python-irodsclient                  1.1.4  pyhd8ed1ab_0         conda-forge/noarch        137kB
#   + python_abi                           3.10  2_cp310              conda-forge/linux-64        4kB
#   + pytz                               2022.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pyu2f                               0.1.5  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pyyaml                                6.0  py310h5764c6d_4      conda-forge/linux-64      183kB
#   + ratelimiter                         1.2.0  py_1002              conda-forge/noarch         12kB
#   + re2                            2022.06.01  h27087fc_0           conda-forge/linux-64     Cached
#   + readline                            8.1.2  h0f457ee_0           conda-forge/linux-64     Cached
#   + requests                           2.28.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + retry                               0.9.2  py_0                 conda-forge/noarch          9kB
#   + rich                               12.5.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + rsa                                   4.9  pyhd8ed1ab_0         conda-forge/noarch         30kB
#   + s3transfer                          0.6.0  pyhd8ed1ab_0         conda-forge/noarch         57kB
#   + setuptools                         63.3.0  py310hff52083_0      conda-forge/linux-64        1MB
#   + setuptools-scm                      7.0.5  pyhd8ed1ab_0         conda-forge/noarch         36kB
#   + six                                1.16.0  pyh6c4a22f_0         conda-forge/noarch       Cached
#   + slacker                            0.14.0  py_0                 conda-forge/noarch         16kB
#   + smart_open                          6.0.0  pyhd8ed1ab_0         conda-forge/noarch         44kB
#   + smmap                               3.0.5  pyh44b312d_0         conda-forge/noarch       Cached
#   + snakemake                          7.12.0  hdfd78af_0           bioconda/noarch             8kB
#   + snakemake-minimal                  7.12.0  pyhdfd78af_0         bioconda/noarch           249kB
#   + sqlite                             3.39.2  h4ff8645_0           conda-forge/linux-64     Cached
#   + stone                               3.3.1  pyhd8ed1ab_0         conda-forge/noarch        149kB
#   + stopit                              1.1.2  py_0                 conda-forge/noarch         16kB
#   + tabulate                           0.8.10  pyhd8ed1ab_0         conda-forge/noarch         30kB
#   + tk                                 8.6.12  h27826a3_0           conda-forge/linux-64     Cached
#   + tomli                               2.0.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + toposort                              1.7  pyhd8ed1ab_0         conda-forge/noarch         13kB
#   + traitlets                           5.3.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + typing-extensions                   4.3.0  hd8ed1ab_0           conda-forge/noarch          8kB
#   + typing_extensions                   4.3.0  pyha770c72_0         conda-forge/noarch       Cached
#   + tzdata                              2022a  h191b570_0           conda-forge/noarch       Cached
#   + ubiquerg                            0.6.2  pyhd8ed1ab_0         conda-forge/noarch         16kB
#   + uritemplate                         4.1.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + urllib3                           1.26.11  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + veracitools                         0.1.3  py_0                 conda-forge/noarch          6kB
#   + wcwidth                             0.2.5  pyh9f0ad1d_2         conda-forge/noarch       Cached
#   + wheel                              0.37.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + wrapt                              1.14.1  py310h5764c6d_0      conda-forge/linux-64       52kB
#   + xz                                  5.2.5  h516909a_1           conda-forge/linux-64     Cached
#   + yaml                                0.2.5  h7f98852_2           conda-forge/linux-64     Cached
#   + yarl                                1.7.2  py310h5764c6d_2      conda-forge/linux-64      136kB
#   + yte                                 1.5.1  py310hff52083_0      conda-forge/linux-64       17kB
#   + zipp                                3.8.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + zlib                               1.2.12  h166bdaf_2           conda-forge/linux-64     Cached
#
#   Summary:
#
#   Install: 167 packages
#
#   Total download: 85MB
#
# ─────────────────────────────────────────────────────────────────────────────────────────────────────
#
# [+] 0.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B                            0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.1s
# Downloading  (5) ━╸━━━━━━━━━━━━━━━━━━━━━   0.0 B coin-or-clp                0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0scoin-or-utils                                      757.5kB @   5.9MB/s  0.1s
# liblapacke                                          12.7kB @  89.4kB/s  0.1s
# coin-or-clp                                          1.3MB @   8.3MB/s  0.2s
# coin-or-osi                                        450.1kB @   2.8MB/s  0.2s
# ply                                                 44.8kB @ 236.4kB/s  0.0s
# ftputil                                             42.9kB @ 217.3kB/s  0.0s
# [+] 0.2s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   3.1MB grpc-cpp                   0.1s
# Extracting   (3) ━━━━━━━━━━━╸━━━━━━━━━━━       1 coin-or-clp                0.0spython-fastjsonschema                              248.8kB @   1.2MB/s  0.0s
# setuptools                                           1.4MB @   6.9MB/s  0.1s
# stopit                                              16.1kB @  68.7kB/s  0.0s
# ratelimiter                                         11.9kB @  49.9kB/s  0.0s
# configargparse                                      32.5kB @ 136.2kB/s  0.0s
# importlib_resources                                 28.3kB @ 115.9kB/s  0.0s
# markupsafe                                          22.7kB @  83.9kB/s  0.0s
# wrapt                                               52.0kB @ 191.5kB/s  0.0s
# retry                                                8.8kB @  32.3kB/s  0.0s
# dpath                                               23.7kB @  85.0kB/s  0.0s
# grpc-cpp                                             5.4MB @  19.2MB/s  0.3s
# [+] 0.3s
# Downloading  (5) ━╸━━━━━╸━━━━━━━━━━━━━━━   9.9MB certifi                    0.2s
# Extracting  (16) ━━━━━━━━━━━━╸━━━━━━━━━━       1 coin-or-clp                0.1scertifi                                            158.9kB @ 532.3kB/s  0.0s
# protobuf                                           333.2kB @   1.0MB/s  0.1s
# cffi                                               237.0kB @ 709.4kB/s  0.1s
# google-crc32c                                       24.2kB @  71.1kB/s  0.0s
# docutils                                           781.1kB @   2.3MB/s  0.1s
# jsonschema                                          63.9kB @ 176.1kB/s  0.0s
# googleapis-common-protos                           125.7kB @ 345.5kB/s  0.0s
# ubiquerg                                            16.0kB @  41.1kB/s  0.1s
# [+] 0.4s
# Downloading  (5) ━━╸━━━━━━━╸━━━━━━━━━━━━  13.2MB botocore                   0.3s
# Extracting  (19) ╸━━━━━╸━━━━━━━━━━━━━━━━       7 coin-or-clp                0.2sparamiko                                           143.4kB @ 350.0kB/s  0.0s
# slacker                                             15.6kB @  34.6kB/s  0.1s
# google-cloud-core                                   28.3kB @  62.6kB/s  0.0s
# [+] 0.5s
# Downloading  (5) ━━━╸━━━━━━━━╸━━━━━━━━━━  17.9MB botocore                   0.4s
# Extracting  (20) ━╸━━━━━╸━━━━━━━━━━━━━━━       8 coin-or-clp                0.3scryptography                                         1.6MB @   3.2MB/s  0.2s
# snakemake                                            8.0kB @  15.5kB/s  0.1s
# coincbc                                              9.9kB @  19.1kB/s  0.1s
# logmuse                                             10.7kB @  19.1kB/s  0.0s
# attrs                                               49.5kB @  86.6kB/s  0.0s
# pkgutil-resolve-name                                 8.7kB @  14.7kB/s  0.0s
# iniconfig                                            8.3kB @  13.9kB/s  0.1s
# botocore                                             5.8MB @   9.7MB/s  0.2s
# [+] 0.6s
# Downloading  (4) ━━━━━╸━━━━━━━━╸━━━━━━━━  26.0MB frozenlist                 0.5s
# Extracting  (22) ━╸━━━━━━╸━━━━━━━━━━━━━━      11 attrs                      0.4styping-extensions                                    8.5kB @  13.8kB/s  0.0s
# oauth2client                                        67.5kB @ 107.7kB/s  0.0s
# pyrsistent                                          94.5kB @ 149.9kB/s  0.0s
# frozenlist                                          44.2kB @  67.8kB/s  0.1s
# psutil                                             358.7kB @ 545.3kB/s  0.0s
# jupyter_core                                        83.7kB @ 126.8kB/s  0.0s
# yarl                                               135.7kB @ 202.1kB/s  0.0s
# attmap                                              13.6kB @  19.8kB/s  0.0s
# [+] 0.7s
# Downloading  (5) ━━━━━━╸━━━━━━━━━╸━━━━━━  29.6MB pandas                     0.6s
# Extracting  (32) ━━╸━━━━━━━━╸━━━━━━━━━━━      12 attrs                      0.5ssetuptools-scm                                      35.8kB @  51.2kB/s  0.0s
# pulp                                               127.8kB @ 180.0kB/s  0.0s
# s3transfer                                          56.7kB @  79.2kB/s  0.0s
# pandas                                              13.1MB @  18.2MB/s  0.4s
# boto3                                               73.7kB @  99.8kB/s  0.0s
# snakemake-minimal                                  249.0kB @ 335.3kB/s  0.0s
# pynacl                                               1.4MB @   1.9MB/s  0.1s
# jmespath                                            21.0kB @  27.5kB/s  0.0s
# filelock                                            12.2kB @  15.7kB/s  0.0s
# [+] 0.8s
# Downloading  (6) ━━━━━━━━╸━━━━━━━━━━━━━━  36.2MB grpcio                     0.7s
# Extracting  (37) ━━━╸━━━━━━━━━╸━━━━━━━━━      16 attrs                      0.6stoposort                                            12.6kB @  15.7kB/s  0.1s
# pysocks                                             28.6kB @  34.9kB/s  0.0s
# stone                                              149.0kB @ 172.3kB/s  0.1s
# brotlipy                                           350.1kB @ 393.6kB/s  0.1s
# grpcio                                             825.2kB @ 921.9kB/s  0.1s
# [+] 0.9s
# Downloading  (5) ━━━━━━━━━━╸━━━━━━━━━━━━  42.3MB aiohttp                    0.8s
# Extracting  (36) ━━━━╸━━━━━━━━━╸━━━━━━━━      20 attrs                      0.7sveracitools                                          6.1kB @   6.7kB/s  0.0s
# google-auth                                         92.1kB @  98.6kB/s  0.0s
# aiohttp                                            599.3kB @ 636.1kB/s  0.1s
# python_abi                                           4.1kB @   4.2kB/s  0.0s
# filechunkio                                          5.1kB @   5.2kB/s  0.0s
# [+] 1.0s
# Downloading  (5) ━━━━━━━━━━━━╸━━━━━━━━━━  49.9MB connection_pool            0.9s
# Extracting  (37) ━━━━━╸━━━━━━━━━━╸━━━━━━      26 aiohttp                    0.8sconnection_pool                                      8.3kB @   8.2kB/s  0.0s
# rsa                                                 29.9kB @  29.4kB/s  0.0s
# numpy                                                7.4MB @   7.2MB/s  0.3s
# pytest                                             475.9kB @ 451.9kB/s  0.0s
# datrie                                             771.5kB @ 721.0kB/s  0.1s
# pysftp                                              15.5kB @  14.3kB/s  0.0s
# google-api-python-client                             5.2MB @   4.7MB/s  0.2s
# [+] 1.1s
# Downloading  (5) ━━━━━━━━━━━━━━━╸━━━━━━━  62.1MB coin-or-cgl                1.0s
# Extracting  (39) ━━━━━━╸━━━━━━━━━━╸━━━━━      30 aiohttp                    0.9spluggy                                              25.8kB @  22.7kB/s  0.0s
# coin-or-cgl                                        603.2kB @ 530.5kB/s  0.1s
# py                                                  76.0kB @  66.9kB/s  0.0s
# amply                                               20.9kB @  17.9kB/s  0.0s
# pyyaml                                             182.6kB @ 155.7kB/s  0.0s
# bcrypt                                              45.4kB @  38.7kB/s  0.0s
# [+] 1.2s
# Downloading  (5) ━━━━━━━━━━━━━━━━━╸━━━━━  68.3MB coin-or-cbc                1.1s
# Extracting  (43) ━━━━━━━╸━━━━━━━━━━━╸━━━      33 aiohttp                    1.0spython-irodsclient                                 137.1kB @ 114.1kB/s  0.2s
# coin-or-cbc                                          1.1MB @ 874.6kB/s  0.0s
# tabulate                                            30.2kB @  24.9kB/s  0.0s
# importlib-metadata                                  34.2kB @  28.1kB/s  0.0s
# plac                                                23.4kB @  18.9kB/s  0.0s
# future                                             755.4kB @ 599.6kB/s  0.0s
# multidict                                           52.7kB @  41.0kB/s  0.0s
# dropbox                                            956.0kB @ 743.9kB/s  0.1s
# [+] 1.3s
# Downloading  (5) ━━━━━━━━━━━━━━━━━━━━╸━━  79.3MB aioeasywebdav              1.2s
# Extracting  (50) ━━━━━━━╸━━━━━━━━━━━━━╸━      34 aiohttp                    1.1saioeasywebdav                                       12.5kB @   9.6kB/s  0.1s
# google-api-core                                     71.9kB @  54.8kB/s  0.1s
# smart_open                                          44.2kB @  33.5kB/s  0.0s
# peppy                                               26.3kB @  19.7kB/s  0.1s
# yte                                                 17.4kB @  13.0kB/s  0.0s
# python                                              30.0MB @  22.3MB/s  0.6s
# [+] 1.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (55) ━━━━━━━╸━━━━━━━━━━━━━━━      35 amply                      1.2s[+] 1.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (55) ━━━━━━━╸━━━━━━━━━━━━━━━      35 amply                      1.3s[+] 1.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (54) ━━━━━━━━╸━━━━━━━━━━━━━━      36 amply                      1.4s[+] 1.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (53) ━━━━━━━━╸━━━━━━━━━━━━━━      37 aioeasywebdav              1.5s[+] 1.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (53) ━━━━━━━━╸━━━━━━━━━━━━━━      37 aioeasywebdav              1.6s[+] 1.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (52) ━━━━━━━━╸━━━━━━━━━━━━━━      38 aioeasywebdav              1.7s[+] 2.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (52) ━━━━━━━━╸━━━━━━━━━━━━━━      38 aioeasywebdav              1.8s[+] 2.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (52) ━━━━━━━━╸━━━━━━━━━━━━━━      38 aiohttp                    1.9s[+] 2.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (51) ━━━━━━━━╸━━━━━━━━━━━━━━      39 aiohttp                    2.0s[+] 2.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (49) ━━━━━━━━━╸━━━━━━━━━━━━━      41 aiohttp                    2.1s[+] 2.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (48) ━━━━━━━━━╸━━━━━━━━━━━━━      42 aiohttp                    2.2s[+] 2.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (48) ━━━━━━━━━╸━━━━━━━━━━━━━      42 attmap                     2.3s[+] 2.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (47) ━━━━━━━━━╸━━━━━━━━━━━━━      43 attmap                     2.4s[+] 2.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (47) ━━━━━━━━━╸━━━━━━━━━━━━━      43 attmap                     2.5s[+] 2.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (44) ━━━━━━━━━━╸━━━━━━━━━━━━      46 attmap                     2.6s[+] 2.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (42) ━━━━━━━━━━━╸━━━━━━━━━━━      48 bcrypt                     2.7s[+] 3.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (40) ━━━━━━━━━━━╸━━━━━━━━━━━      50 bcrypt                     2.8s[+] 3.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (38) ━━━━━━━━━━━━╸━━━━━━━━━━      52 bcrypt                     2.9s[+] 3.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (35) ━━━━━━━━━━━━━╸━━━━━━━━━      55 bcrypt                     3.0s[+] 3.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (34) ━━━━━━━━━━━━━╸━━━━━━━━━      56 botocore                   3.1s[+] 3.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (30) ━━━━━━━━━━━━━━╸━━━━━━━━      60 botocore                   3.2s[+] 3.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (28) ━━━━━━━━━━━━━━╸━━━━━━━━      62 botocore                   3.3s[+] 3.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (25) ━━━━━━━━━━━━━━━╸━━━━━━━      65 botocore                   3.4s[+] 3.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (24) ━━━━━━━━━━━━━━━╸━━━━━━━      66 coin-or-cbc                3.5s[+] 3.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (23) ━━━━━━━━━━━━━━━━╸━━━━━━      67 coin-or-cbc                3.6s[+] 3.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (20) ━━━━━━━━━━━━━━━━╸━━━━━━      70 coin-or-cbc                3.7s[+] 4.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (18) ━━━━━━━━━━━━━━━━━╸━━━━━      72 coin-or-cbc                3.8s[+] 4.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (15) ━━━━━━━━━━━━━━━━━━╸━━━━      75 connection_pool            3.9s[+] 4.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting  (13) ━━━━━━━━━━━━━━━━━━╸━━━━      77 connection_pool            4.0s[+] 4.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (9) ━━━━━━━━━━━━━━━━━━━╸━━━      81 botocore                   4.1s[+] 4.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (6) ━━━━━━━━━━━━━━━━━━━━╸━━      84 botocore                   4.2s[+] 4.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (5) ━━━━━━━━━━━━━━━━━━━━╸━━      85 botocore                   4.3s[+] 4.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (5) ━━━━━━━━━━━━━━━━━━━━╸━━      85 botocore                   4.4s[+] 4.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 google-api-python-client   4.5s[+] 4.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 google-api-python-client   4.6s[+] 4.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 google-api-python-client   4.7s[+] 5.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 google-api-python-client   4.8s[+] 5.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 python                     4.9s[+] 5.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 python                     5.0s[+] 5.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 python                     5.1s[+] 5.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 python                     5.2s[+] 5.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 botocore                   5.3s[+] 5.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 botocore                   5.4s[+] 5.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 botocore                   5.5s[+] 5.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 botocore                   5.6s[+] 5.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 google-api-python-client   5.7s[+] 6.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 google-api-python-client   5.8s[+] 6.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━━╸━      87 google-api-python-client   5.9s[+] 6.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━━╸━      88 botocore                   6.0s[+] 6.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━━╸━      88 botocore                   6.1s[+] 6.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━━╸━      88 botocore                   6.2s[+] 6.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━━╸━      88 botocore                   6.3s[+] 6.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━━╸━      88 python                     6.4s[+] 6.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━━╸━      88 python                     6.5s[+] 6.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      89 python                     6.6s[+] 6.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      89 python                     6.7s[+] 7.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      89 python                     6.8s[+] 7.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      89 python                     6.9s[+] 7.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      89 python                     7.0s[+] 7.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  85.4MB                            1.3s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━      90                            7.1sPreparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Installing pip dependencies: \ Ran pip subprocess with arguments:
# ['/opt/conda/envs/snakemake/bin/python', '-m', 'pip', 'install', '-U', '-r', '/home/jupyter/condaenv.f9a1h2xy.requirements.txt']
# Pip subprocess output:
# Collecting jupyterlab
#   Using cached jupyterlab-3.4.4-py3-none-any.whl (8.8 MB)
# Collecting jupyterlab-server~=2.10
#   Using cached jupyterlab_server-2.15.0-py3-none-any.whl (54 kB)
# Collecting ipython
#   Using cached ipython-8.4.0-py3-none-any.whl (750 kB)
# Collecting notebook<7
#   Using cached notebook-6.4.12-py3-none-any.whl (9.9 MB)
# Requirement already satisfied: jupyter-core in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (4.11.1)
# Requirement already satisfied: packaging in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (21.3)
# Collecting tornado>=6.1.0
#   Using cached tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
# Collecting jupyter-server~=1.16
#   Using cached jupyter_server-1.18.1-py3-none-any.whl (344 kB)
# Requirement already satisfied: jinja2>=2.1 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (3.1.2)
# Collecting nbclassic
#   Using cached nbclassic-0.4.3-py3-none-any.whl (9.7 MB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jinja2>=2.1->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (2.1.1)
# Collecting anyio<4,>=3.1.0
#   Using cached anyio-3.6.1-py3-none-any.whl (80 kB)
# Collecting websocket-client
#   Using cached websocket_client-1.3.3-py3-none-any.whl (54 kB)
# Collecting Send2Trash
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: nbformat>=5.2.0 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (5.4.0)
# Collecting jupyter-client>=6.1.12
#   Using cached jupyter_client-7.3.4-py3-none-any.whl (132 kB)
# Collecting prometheus-client
#   Using cached prometheus_client-0.14.1-py3-none-any.whl (59 kB)
# Collecting nbconvert>=6.4.4
#   Using cached nbconvert-6.5.0-py3-none-any.whl (561 kB)
# Requirement already satisfied: traitlets>=5.1 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jupyter-server~=1.16->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (5.3.0)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting pyzmq>=17
#   Downloading pyzmq-23.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.9 MB/s eta 0:00:00
# Collecting terminado>=0.8.3
#   Using cached terminado-0.15.0-py3-none-any.whl (16 kB)
# Collecting babel
#   Using cached Babel-2.10.3-py3-none-any.whl (9.5 MB)
# Requirement already satisfied: requests in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jupyterlab-server~=2.10->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: jsonschema>=3.0.1 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jupyterlab-server~=2.10->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (4.9.1)
# Collecting json5
#   Using cached json5-0.9.9-py2.py3-none-any.whl (18 kB)
# Collecting nest-asyncio>=1.5
#   Using cached nest_asyncio-1.5.5-py3-none-any.whl (5.2 kB)
# Collecting ipykernel
#   Using cached ipykernel-6.15.1-py3-none-any.whl (132 kB)
# Collecting ipython-genutils
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting pickleshare
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Requirement already satisfied: decorator in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from ipython->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (5.1.1)
# Collecting backcall
#   Using cached backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from ipython->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (63.3.0)
# Collecting pexpect>4.3
#   Using cached pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# Collecting jedi>=0.16
#   Using cached jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Using cached prompt_toolkit-3.0.30-py3-none-any.whl (381 kB)
# Collecting matplotlib-inline
#   Using cached matplotlib_inline-0.1.3-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from ipython->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (2.12.0)
# Collecting stack-data
#   Using cached stack_data-0.3.0-py3-none-any.whl (23 kB)
# Collecting notebook-shim>=0.1.0
#   Using cached notebook_shim-0.1.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from packaging->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (3.0.9)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (3.3)
# Collecting parso<0.9.0,>=0.8.0
#   Using cached parso-0.8.3-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (22.1.0)
# Collecting entrypoints
#   Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (2.8.2)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.6.6-py3-none-any.whl (71 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: defusedxml in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (0.7.1)
# Collecting mistune<2,>=0.8.1
#   Using cached mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting bleach
#   Using cached bleach-5.0.1-py3-none-any.whl (160 kB)
# Collecting tinycss2
#   Using cached tinycss2-1.1.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: fastjsonschema in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from nbformat>=5.2.0->jupyter-server~=1.16->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (2.16.1)
# Collecting ptyprocess>=0.5
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: wcwidth in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (0.2.5)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Requirement already satisfied: pytz>=2015.7 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from babel->jupyterlab-server~=2.10->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: psutil in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from ipykernel->notebook<7->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (5.9.1)
# Collecting debugpy>=1.0
#   Downloading debugpy-1.6.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from requests->jupyterlab-server~=2.10->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (2.1.0)
# Collecting asttokens
#   Using cached asttokens-2.0.5-py2.py3-none-any.whl (20 kB)
# Collecting executing
#   Using cached executing-0.9.1-py2.py3-none-any.whl (16 kB)
# Collecting pure-eval
#   Using cached pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (1.15.1)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pycparser in /opt/conda/envs/snakemake/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab->-r /home/jupyter/condaenv.f9a1h2xy.requirements.txt (line 1)) (2.21)
# Installing collected packages: webencodings, Send2Trash, pure-eval, ptyprocess, pickleshare, mistune, json5, ipython-genutils, executing, backcall, websocket-client, tornado, tinycss2, soupsieve, sniffio, pyzmq, prompt-toolkit, prometheus-client, pexpect, parso, pandocfilters, nest-asyncio, matplotlib-inline, jupyterlab-pygments, entrypoints, debugpy, bleach, babel, asttokens, terminado, stack-data, jupyter-client, jedi, beautifulsoup4, argon2-cffi-bindings, anyio, nbclient, ipython, argon2-cffi, nbconvert, ipykernel, notebook, jupyter-server, notebook-shim, jupyterlab-server, nbclassic, jupyterlab
# Successfully installed Send2Trash-1.8.0 anyio-3.6.1 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 asttokens-2.0.5 babel-2.10.3 backcall-0.2.0 beautifulsoup4-4.11.1 bleach-5.0.1 debugpy-1.6.2 entrypoints-0.4 executing-0.9.1 ipykernel-6.15.1 ipython-8.4.0 ipython-genutils-0.2.0 jedi-0.18.1 json5-0.9.9 jupyter-client-7.3.4 jupyter-server-1.18.1 jupyterlab-3.4.4 jupyterlab-pygments-0.2.2 jupyterlab-server-2.15.0 matplotlib-inline-0.1.3 mistune-0.8.4 nbclassic-0.4.3 nbclient-0.6.6 nbconvert-6.5.0 nest-asyncio-1.5.5 notebook-6.4.12 notebook-shim-0.1.0 pandocfilters-1.5.0 parso-0.8.3 pexpect-4.8.0 pickleshare-0.7.5 prometheus-client-0.14.1 prompt-toolkit-3.0.30 ptyprocess-0.7.0 pure-eval-0.2.2 pyzmq-23.2.0 sniffio-1.2.0 soupsieve-2.3.2.post1 stack-data-0.3.0 terminado-0.15.0 tinycss2-1.1.1 tornado-6.2 webencodings-0.5.1 websocket-client-1.3.3
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate snakemake
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
